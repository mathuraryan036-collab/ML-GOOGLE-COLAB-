# %% [markdown]
# <a href="https://colab.research.google.com/github/mathuraryan036-collab/ML-GOOGLE-COLAB-/blob/main/3_2_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Library:
# useful for data processing and analysis
#
# Panda Data Frames:
# Panda DataFrame is a 2-D data structure with labelled axes (rows and columns)

# %%
# importing pandas and numpy library
import pandas as pd
import numpy as np

# %% [markdown]
# #Creating a pandas DataFrame

# %%
# importing the california house price data
from sklearn.datasets import fetch_california_housing

# %%
housing = fetch_california_housing()

# %%
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(housing)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %%
# pandas DataFrame
df = pd.DataFrame(housing.data, columns=housing.feature_names)

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
df.shape
# Out:
# (20640, 8)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# #Importing the data from a CSV file to a pandas DataFrame

# %%
# csv file to padnas DataFrame
diabetes_df = pd.read_csv('/content/diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# # Loading the data from a excel file to a Pandas DataFrame
#
# pd.read_excel('file path')

# %% [markdown]
# #Exporting a DataFrame to a csv file

# %%
df.to_csv('california_housing.csv')

# %% [markdown]
# # Exporting the pandas DataFrame to an excel file
#
# df.to_excel('filename')

# %% [markdown]
# # Creating a DataFrame with random values

# %%
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.484283  0.915686  0.814796  0.868493  0.779228  0.956756  0.362043
# 1  0.870399  0.719612  0.476123  0.293939  0.848705  0.286394  0.202463
# 2  0.395925  0.555812  0.216328  0.337101  0.624766  0.687045  0.144320
# 3  0.141906  0.189246  0.224439  0.351997  0.827637  0.183500  0.160020
# 4  0.021842  0.601766  0.046693  0.200775  0.244338  0.238753  0.916217
#
#           7         8         9
# 0  0.667433  0.326938  0.692743
# 1  0.227170  0.737961  0.267328
# 2  0.836888  0.410420  0.883857
# 3  0.815074  0.215741  0.601691
# 4  0.694041  0.631183  0.011491

# %%
random_df.shape
# Out:
# (20, 10)

# %% [markdown]
# # Inspecting a DataFrame

# %%
# finding the no. of rows and columns
df.shape
# Out:
# (20640, 8)

# %%
# first 5 rows in a DataFrame
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# last 5 rows of the DataFrame
df.tail()
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 20635    -121.09
# 20636    -121.21
# 20637    -121.22
# 20638    -121.32
# 20639    -121.24

# %%
# information about the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
# dtypes: float64(8)
# memory usage: 1.3 MB

# %%
# finding the number of missing values
df.isnull().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
# diabetes DataFrame
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# counting the values based on the labels
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# group the values based on the mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# # Statistical Measures

# %%
# count or number of values
df.count()
# Out:
# MedInc        20640
# HouseAge      20640
# AveRooms      20640
# AveBedrms     20640
# Population    20640
# AveOccup      20640
# Latitude      20640
# Longitude     20640
# dtype: int64

# %%
# mean value - column wise
df.mean()
# Out:
# MedInc           3.870671
# HouseAge        28.639486
# AveRooms         5.429000
# AveBedrms        1.096675
# Population    1425.476744
# AveOccup         3.070655
# Latitude        35.631861
# Longitude     -119.569704
# dtype: float64

# %%
# standard deviation - column wise
df.std()
# Out:
# MedInc           1.899822
# HouseAge        12.585558
# AveRooms         2.474173
# AveBedrms        0.473911
# Population    1132.462122
# AveOccup        10.386050
# Latitude         2.135952
# Longitude        2.003532
# dtype: float64

# %%
# minimum value
df.min()
# Out:
# MedInc          0.499900
# HouseAge        1.000000
# AveRooms        0.846154
# AveBedrms       0.333333
# Population      3.000000
# AveOccup        0.692308
# Latitude       32.540000
# Longitude    -124.350000
# dtype: float64

# %%
# maximum value - column wise
df.max()
# Out:
# MedInc           15.000100
# HouseAge         52.000000
# AveRooms        141.909091
# AveBedrms        34.066667
# Population    35682.000000
# AveOccup       1243.333333
# Latitude         41.950000
# Longitude      -114.310000
# dtype: float64

# %%
# all the statistical measures about the DataFrame
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %% [markdown]
# # Manipulating a DataFrame

# %%
# adding a column to the DataFrame
df[ ' Price ' ] = housing.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude   Price
# 0    -122.23    4.526
# 1    -122.22    3.585
# 2    -122.24    3.521
# 3    -122.25    3.413
# 4    -122.25    3.422

# %%
# remove a row
df.drop(index = 0 , axis = 0)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude   Price
# ...

# %%
# remove a column
df.drop(columns = 'Population' , axis = 1)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  AveOccup  Latitude  Longitude  \
# 0      8.3252      41.0  6.984127   1.023810  2.555556     37.88    -122.23
# 1      8.3014      21.0  6.238137   0.971880  2.109842     37.86    -122.22
# 2      7.2574      52.0  8.288136   1.073446  2.802260     37.85    -122.24
# 3      5.6431      52.0  5.817352   1.073059  2.547945     37.85    -122.25
# 4      3.8462      52.0  6.281853   1.081081  2.181467     37.85    -122.25
# ...       ...       ...       ...        ...       ...       ...        ...
# 20635  1.5603      25.0  5.045455   1.133333  2.560606     39.48    -121.09
# 20636  2.5568      18.0  6.114035   1.315789  3.122807     39.49    -121.21
# 20637  1.7000      17.0  5.205543   1.120092  2.325635     39.43    -121.22
# 20638  1.8672      18.0  5.329513   1.171920  2.123209     39.43    -121.32
# 20639  2.3886      16.0  5.254717   1.162264  2.616981     39.37    -121.24
#
#         Price
# 0        4.526
# 1        3.585
# ...

# %%
# locating a row using the index value
df.iloc[2]
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude       37.850000
# Longitude    -122.240000
#  Price          3.521000
# Name: 2, dtype: float64

# %%
# locating a column using the index value
print(df.iloc[:,0]) # first column
print(df.iloc[:,1]) # second column
print(df.iloc[:,2]) # third column
print(df.iloc[:,-1]) # last column
# Out:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: MedInc, Length: 20640, dtype: float64
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: HouseAge, Length: 20640, dtype: float64
# 0        6.984127
# 1        6.238137
# 2        8.288136
# 3        5.817352
# 4        6.281853
#            ...
# 20635    5.045455
# 20636    6.114035
# 20637    5.205543
# 20638    5.329513
# 20639    5.254717
# Name: AveRooms, Length: 20640, dtype: float64
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name:  Price , Length: 20640, dtype: float64

# %% [markdown]
# # Correlation
#
# 1. Positive correlation - one increases the other also increases and vice versa
# 2. Negative correlation - one increases the other decreases and vice versa

# %%
df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
#  Price      0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude    Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...
