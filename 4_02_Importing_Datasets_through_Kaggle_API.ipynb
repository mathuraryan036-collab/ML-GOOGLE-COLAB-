# %% [markdown]
# <a href="https://colab.research.google.com/github/mathuraryan036-collab/ML-GOOGLE-COLAB-/blob/main/4_2_Importing_Datasets_through_Kaggle_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# API - Application Programming Interface

# %%
# installing the kaggle library
# !pip install kaggle

# %% [markdown]
# Upload your kaggle.json file

# %%
# configuring the path of kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Importing the Earthquake dataset

# %%
# API to fetch the dataset form the kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
# 100% 2.27G/2.27G [01:15<00:00, 43.5MB/s]
# 100% 2.27G/2.27G [01:15<00:00, 32.4MB/s]

# %%
# extracting rhe compressed Dataset
from zipfile import ZipFile
dataset = '/content/LANL-Earthquake-Prediction.zip'
with ZipFile(dataset,'r') as zip:
  zip.extractall()
  print('The dataset is extracted')
# Out:
# The dataset is extracted
