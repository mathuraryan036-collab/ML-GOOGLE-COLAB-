# %%
import numpy as np

# %% [markdown]
# Dot Product of 2 Vectors

# %%
a = np.array([2, 3])
b = np.array([4, 4])
a_dot_b = np.dot(a, b)

# %%
print(a_dot_b)
# Out:
# 20

# %%
c = np.array([40, 20, 35])
d = np.array([53, 24, 68])
c_dot_d = np.dot(c, d)
print(c_dot_d)
# Out:
# 4980

# %% [markdown]
# Cross Product of 2 Vectors

# %%
a = np.array([2, 3])
b = np.array([4, 4])
a_cross_b = np.cross(a, b)
print(a_cross_b)
# Out:
# -4
# /tmp/ipykernel_12159/3903711138.py:3: DeprecationWarning: Arrays of 2-dimensional vectors are deprecated. Use arrays of 3-dimensional vectors instead. (deprecated in NumPy 2.0)
#   a_cross_b = np.cross(a, b)

# %%
c = np.array([5, 10, 20])
d = np.array([38, 32, 50])
c_cross_d = np.cross(c, d)
print(c_cross_d)
# Out:
# [-140  510 -220]

# %% [markdown]
# Projection of "a" Vector on "v" Vector

# %%
a = np.array([2, 5])
v = np.array([8, -6])
#magnitude of "v" vector
magnitude_of_v = np.sqrt(sum(v**2))
proj_of_a_on_v = (np.dot(a, v)/magnitude_of_v**2)*v
print('Projection of a vector on v vector = ', proj_of_a_on_v)
# Out:
# Projection of a vector on v vector =  [-1.12  0.84]

# %%
a = np.array([23, 45, 62])
v = np.array([45, 82, 67])
#magnitude of "v" vector
magnitude_of_v = np.sqrt(sum(v**2))
proj_of_a_on_v = (np.dot(a, v)/magnitude_of_v**2)*v
print('Projection of a vector on v vector = ', proj_of_a_on_v)
# Out:
# Projection of a vector on v vector =  [30.18242937 54.99909352 44.93828373]
